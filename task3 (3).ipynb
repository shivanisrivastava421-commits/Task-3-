# %%
import pandas as pd
import numpy  as np
from numpy import array
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv('/content/AAPL.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# ...

# %% [markdown]
# symbol: The stock ticker symbol — here it's AAPL (Apple Inc.).
#
# date: The trading date for each record.
#
# close: The closing price of the stock on that date.
#
# high: The highest price reached during that day.
#
# low :The lowest price reached during that day.
#
# open: The opening price of the stock on that day.
#
# volume: The number of shares traded on that day.
#
# adjClose: The adjusted closing price, accounting for splits/dividends.
#
# adjHigh: The adjusted high price after stock adjustments.
#
# adjLow: The adjusted low price after stock adjustments.
#
# adjOpen: The adjusted open price after stock adjustments.
#
# adjVolume: The adjusted trading volume.
#
# divCash: The dividend amount (cash paid per share on that date). splitFactor The stock split factor

# %%
df.shape
# Out:
# (1258, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1258 non-null   int64
#  1   symbol       1258 non-null   object
#  2   date         1258 non-null   object
#  3   close        1258 non-null   float64
#  4   high         1258 non-null   float64
#  5   low          1258 non-null   float64
#  6   open         1258 non-null   float64
#  7   volume       1258 non-null   int64
#  8   adjClose     1258 non-null   float64
#  9   adjHigh      1258 non-null   float64
#  10  adjLow       1258 non-null   float64
#  11  adjOpen      1258 non-null   float64
#  12  adjVolume    1258 non-null   int64
#  13  divCash      1258 non-null   float64
#  14  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(3), object(2)
# memory usage: 147.6+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0        close         high          low         open  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    628.500000   167.723998   169.230475   166.039780   167.548266
# std     363.297628    56.850796    57.500128    56.006773    56.612707
# min       0.000000    90.340000    91.670000    89.470000    90.000000
# 25%     314.250000   116.327500   117.405000   115.602500   116.482500
# 50%     628.500000   160.485000   162.080000   158.974250   160.345000
# 75%     942.750000   199.785000   201.277500   198.170000   199.520000
# max    1257.000000   327.200000   327.850000   323.350000   324.730000
#
#              volume     adjClose      adjHigh       adjLow      adjOpen  \
# count  1.258000e+03  1258.000000  1258.000000  1258.000000  1258.000000
# mean   3.500397e+07   162.666715   164.131054   161.028013   162.493082
# std    1.729100e+07    58.733820    59.402842    57.869246    58.494560
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
plt.figure(figsize=(20, 10))  # Set figure size
plt.figure(figsize=(20, 10))  # Set figure size

plt.plot(df['open'], label='Open', color='blue')     # Blue for Open
plt.plot(df['high'], label='High', color='green')    # Green for High
plt.plot(df['low'], label='Low', color='red')        # Red for Low
plt.plot(df['close'], label='Close', color='orange')

# %%
df1=df.reset_index()['close']

# %%
df1.shape
# Out:
# (1258,)

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %% [markdown]
# Applying minmax scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df.reset_index()['close']).reshape(-1,1))

# %%
df1
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        ...,
#        [0.96635143],
#        [0.9563033 ],
#        [0.96491598]])

# %%
#splitting of data into train and test
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (817, 441)

# %%
train_data
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        [0.1696994 ],
#        [0.16727181],
#        [0.16794731],
#        [0.16473866],
#        [0.16174111],
#        [0.1581525 ],
#        [0.15654817],
#        [0.16271215],
#        [0.1614878 ],
#        [0.1554927 ],
#        [0.15443722],
#        [0.15730811],
#        [0.15604154],
#        [0.15849025],
#        [0.15308621],
#        [0.15735033],
#        [0.15490163],
#        [0.15946129],
#        [0.15688592],
#        [0.1537195 ],
#        [0.14434687],
#        [0.14812547],
#        [0.15308621],
#        [0.15241071],
#        [0.15055307],
#        [0.14924428],
#        [0.13607194],
#        [0.12551718],
#        [0.13906949],
#        [0.14911762],
#        [0.14890653],
#        [0.15401503],
#        [0.16115005],
#        [0.16583636],
#        [0.17618002],
#        [0.17060711],
#        [0.14725998],
#        [0.14700667],
#        [0.14422021],
#        [0.13691632],
# ...

# %%
#convert array of values into a dataset matrix
def create_dataset(dataset,time_step=1):
  dataX,dataY=[],[]
  for i in range(len(dataset)-time_step-1):
    a=dataset[i:(i+time_step),0]
    dataX.append(a)
    dataY.append(dataset[i+time_step,0])
  return np.array(dataX),np.array(dataY)

# %%
#reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step=100
X_train,y_train=create_dataset(train_data,time_step)
X_test,y_test=create_dataset(test_data,time_step)

# %%
X_train.shape,y_train.shape
# Out:
# ((716, 100), (716,))

# %%
X_train
# Out:
# array([[0.17607447, 0.17495567, 0.16862282, ..., 0.09055982, 0.08388922,
#         0.09085536],
#        [0.17495567, 0.16862282, 0.1696994 , ..., 0.08388922, 0.09085536,
#         0.0873934 ],
#        [0.16862282, 0.1696994 , 0.16727181, ..., 0.09085536, 0.0873934 ,
#         0.09030651],
#        ...,
#        [0.34801148, 0.32930845, 0.32145571, ..., 0.50042219, 0.50413747,
#         0.5062062 ],
#        [0.32930845, 0.32145571, 0.32694419, ..., 0.50413747, 0.5062062 ,
#         0.51920966],
#        [0.32145571, 0.32694419, 0.32230009, ..., 0.5062062 , 0.51920966,
#         0.53719497]])

# %%
#we have to reshape input which is required for LSTM
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %% [markdown]
# ## Creating stacked LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input

model = Sequential([
    Input(shape=(100, 1)),
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    LSTM(64),
    Dense(32, activation='relu'),
    Dense(1)
])
model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 64)        │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 0.0361 - val_loss: 0.0297
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.6854e-04 - val_loss: 0.0034
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.8085e-04 - val_loss: 0.0036
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.6210e-04 - val_loss: 0.0036
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0779e-04 - val_loss: 0.0035
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0584e-04 - val_loss: 0.0035
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1591e-04 - val_loss: 0.0031
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1198e-04 - val_loss: 0.0034
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0095e-04 - val_loss: 0.0029
# Epoch 11/100
# ...

# %%
import tensorflow as tf

# %%
#doing prediction and checking performance matrix
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
#transformback to orignal form
'''train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)'''

y_train_actual = scaler.inverse_transform(y_train.reshape(-1,1))
y_test_actual  = scaler.inverse_transform(y_test.reshape(-1,1))
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
#Calculate RMSE performance metrics for training data
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 141.6223132104148

# %%
# Test Data RMSE
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 237.45269637205303

# %%
#shift train prediction fr plotting
look_back=100
trainPredictPlot=np.empty_like(df1)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:]=train_predict
#shift test prediction for plotting
testPredictPlot=np.empty_like(df1)
testPredictPlot[:,:]=np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]=test_predict
#plot basicline and prediction
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Here we are predicting the cost prices so the green colour is the predicted output through test data and the blue colour is our dataset and the orange colour is out training dataset.

# %%
plt.figure(figsize=(10,6))
plt.plot(y_test_actual, label='Actual Price')
plt.plot(test_predict, label='Predicted Price')
plt.title('Actual vs Predicted Stock Prices')
plt.legend()
plt.show()

# %% [markdown]
# Now lets predict the future the 30 days and plot the output

# %%
len(test_data)
# Out:
# 441

# %%
#taking data from 341 to 441 data and reshaping it
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
#converting into a list
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.8583551465000423,
#  0.8866418981676942,
#  0.8743139407244789,
#  0.8843198513890065,
#  0.8783669678290975,
#  0.8986321033521913,
#  0.925821160179009,
#  0.9287764924427933,
#  0.9567677108840666,
#  0.9386979650426415,
#  0.933040614709111,
#  0.9495060373216249,
#  0.9642404796082076,
#  0.9551211686228154,
#  0.9598919192772104,
#  0.9663514312251966,
#  0.9624672802499368,
#  0.9229502659799038,
#  0.9598497002448705,
#  0.9879253567508233,
#  0.985941062230854,
#  0.9253145317909315,
#  0.9217259140420504,
#  0.964747107996285,
#  0.9757240564046274,
#  0.9915984125643842,
#  0.9697289538123788,
#  0.9761462467280253,
#  0.9679557544541082,
#  1.0000000000000002,
#  0.9901629654648318,
#  0.9905007177235499,
#  0.9653803934813816,
#  0.9848855864223593,
#  0.9708688676855528,
#  0.9402600692392133,
#  0.8774803681499621,
#  0.8348391454867856,
#  0.8541332432660644,
#  0.7733682344000676,
#  0.7726927298826314,
#  0.8801401671873683,
#  0.8400743054969182,
# ...

# %%
#predicting the next 30 days
lst_output=[]
n_steps=100
i=0
while(i<30):
  if(len(temp_input)>100):
    #print(temp_input)
    x_input=np.array(temp_input[1:])
    print("{} day input {}".format(i,x_input))
    x_input=x_input.reshape(1,-1)
    x_input=x_input.reshape((1,n_steps,1))
    #print(x_input)
    yhat=model.predict(x_input,verbose=0)
    print("{} day output {}".format(i,yhat))
    temp_input.extend(yhat[0].tolist())
    temp_input=temp_input[1:]
    #print(temp_input)
    lst_output.extend(yhat.tolist())
    i=i+1
  else:
    x_input=x_input.reshape((1,n_steps,1))
    yhat=model.predict(x_input,verbose=0)
    print(yhat[0])
    temp_input.extend(yhat[0].tolist())
    print(len(temp_input))
    lst_output.extend(yhat.tolist())
    i=i+1
print(lst_output)
# Out:
# [0.95196605]
# 101
# 1 day input [0.8866419  0.87431394 0.88431985 0.87836697 0.8986321  0.92582116
#  0.92877649 0.95676771 0.93869797 0.93304061 0.94950604 0.96424048
#  0.95512117 0.95989192 0.96635143 0.96246728 0.92295027 0.9598497
#  0.98792536 0.98594106 0.92531453 0.92172591 0.96474711 0.97572406
#  0.99159841 0.96972895 0.97614625 0.96795575 1.         0.99016297
#  0.99050072 0.96538039 0.98488559 0.97086887 0.94026007 0.87748037
#  0.83483915 0.85413324 0.77336823 0.77269273 0.88014017 0.84007431
#  0.89673225 0.85527316 0.83884995 0.74233725 0.82327113 0.78143207
#  0.6665963  0.7921557  0.64118044 0.68614371 0.66001013 0.65203074
#  0.58642236 0.56586169 0.66089673 0.65515494 0.70970193 0.66452757
#  0.69437642 0.69218104 0.63569197 0.65266402 0.63780292 0.7267162
#  0.71388162 0.74191506 0.75002111 0.77222832 0.83049059 0.8194292
#  0.8289707  0.8125475  0.78776492 0.75162543 0.78426074 0.77974331
#  0.81326522 0.8141096  0.79473106 0.83336148 0.85898843 0.83901883
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
len(df1)
# Out:
# 1258

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[1200:])

# %%
plt.plot(day_new,scaler.inverse_transform(df1[1158:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
plt.figure(figsize=(10,6))
plt.plot(y_test_actual, label='Actual')
plt.plot(test_predict, label='Predicted')
plt.legend()
plt.title("Model Prediction vs Actual")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# Calculate MAE for training data
train_mae = mean_absolute_error(y_train_actual, train_predict)
print(f"Training Data MAE: {train_mae}")

# Calculate MAE for test data
test_mae = mean_absolute_error(y_test_actual, test_predict)
print(f"Test Data MAE: {test_mae}")

# Evaluate the model on the test data to get the loss (MSE)
test_loss = model.evaluate(X_test, y_test, verbose=2)
print(f'Test Loss (MSE): {test_loss:.6f}')
# Out:
# Training Data MAE: 2.0784191442734707
# Test Data MAE: 5.041366932588464
# 11/11 - 0s - 10ms/step - loss: 9.5298e-04
# Test Loss (MSE): 0.000953
